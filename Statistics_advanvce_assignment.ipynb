# %%
# Q1. The three measures of central tendency are:
# 1. Mean
# 2. Median
# 3. Mode

# Q2. The difference between mean, median, and mode:
# - Mean is the arithmetic average of a dataset, calculated by adding all values and dividing by the number of values.
# - Median is the middle value of a dataset when it is arranged in ascending or descending order.
# - Mode is the most frequent value in a dataset.

# These measures help summarize a dataset by providing a central or typical value. Mean is used when data is symmetric,
# median is used when the data is skewed, and mode is useful when the data has repeated values.

# Q3. To calculate the three measures of central tendency for the given height data:
heights = [178,177,176,177,178.2,178,175,179,180,175,178.9,176.2,177,172.5,178,176.5]

# Mean
mean_height = sum(heights) / len(heights)

# Median
heights_sorted = sorted(heights)
n = len(heights_sorted)
if n % 2 == 0:
    median_height = (heights_sorted[n//2 - 1] + heights_sorted[n//2]) / 2
else:
    median_height = heights_sorted[n//2]

# Mode
from statistics import mode
mode_height = mode(heights)

# Q4. To find the standard deviation for the given data:
import math

# Calculate variance
variance_height = sum((x - mean_height)**2 for x in heights) / len(heights)

# Standard deviation is the square root of variance
std_dev_height = math.sqrt(variance_height)

# Q5. Measures of dispersion describe the spread of a dataset:
# - Range: The difference between the highest and lowest values in the dataset.
# - Variance: The average of squared differences from the mean, measures the spread.
# - Standard deviation: The square root of variance, represents the average distance from the mean.

# Example: For heights, we can calculate the range as the difference between max and min values, variance and standard deviation
# as shown in Q4.

# Q6. A Venn diagram is a graphical representation of sets and their relationships, often used to illustrate the
# intersection, union, and differences between two or more sets.

# Q7. For the two sets A = (2,3,4,5,6,7) & B = (0,2,6,8,10):
A = {2, 3, 4, 5, 6, 7}
B = {0, 2, 6, 8, 10}

# (i) A ∩ B (Intersection)
intersection = A.intersection(B)

# (ii) A ∪ B (Union)
union = A.union(B)

# Q8. Skewness refers to the asymmetry or lack of symmetry in a dataset. A positively skewed (right-skewed) distribution
# has a longer right tail, while a negatively skewed (left-skewed) distribution has a longer left tail.

# Q9. In a right-skewed data, the mean will be greater than the median, and the median will be located to the left of the mean.

# Q10. Covariance measures the directional relationship between two random variables, while correlation measures both
# the strength and direction of the linear relationship. Covariance is influenced by the scale of the variables, whereas
# correlation is a standardized measure.

# Q11. The formula for calculating the sample mean is:
# Mean = (Sum of all data points) / (Number of data points)

# Example: For dataset [4, 8, 6, 5]:
# Mean = (4 + 8 + 6 + 5) / 4 = 23 / 4 = 5.75

# Q12. For a normal distribution, the mean, median, and mode are all equal and located at the center of the distribution.

# Q13. Covariance measures how two variables change together, while correlation is a standardized version of covariance
# that gives a measure of both the strength and direction of the linear relationship between the variables.

# Q14. Outliers can heavily impact measures of central tendency and dispersion. For example, in a dataset with
# the values [1, 2, 3, 4, 100], the mean is heavily influenced by the outlier (100), whereas the median is less
# affected and remains at 3. The standard deviation would also be large due to the outlier, while the interquartile range
# (a robust measure of dispersion) would remain more stable.
